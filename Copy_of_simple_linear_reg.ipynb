# %% [markdown]
# <a href="https://colab.research.google.com/github/Seyospogi/Zyrus/blob/main/Copy_of_simple_linear_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Experience Years', y='Salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Experience Years']
#   ys = series['Salary']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('Experience Years', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Experience Years')
# _ = plt.ylabel('Salary')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Experience Years']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Experience Years'}, axis=1)
#               .sort_values('Experience Years', ascending=True))
#   xs = counted['Experience Years']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('Experience Years', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Experience Years')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Experience Years'].plot(kind='line', figsize=(8, 4), title='Experience Years')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Salary'].plot(kind='line', figsize=(8, 4), title='Salary')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
X_simple = df[['Experience Years']]
y = df['Salary']
simple_model = LinearRegression()
simple_model.fit(X_simple, y)
# Out:
# LinearRegression()

# %%
#Prediction of X
y_pred = simple_model.predict(X_simple)

# %%
print(y_pred.max())
# Out:
# 125671.34608841618

# %%
print(y_pred.min())
# Out:
# 36149.031318689755

# %%
plt.scatter(X_simple, y, color='blue')
plt.plot(X_simple, y_pred, color='red')
plt.title("Simple Linear Regression")
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.show()
